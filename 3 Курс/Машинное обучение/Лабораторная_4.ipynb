# %% [markdown]
# Журавлев К. В. ПИ20-1 Лабораторная работа 4

# %% [markdown]
# **Задание 0**
#
# Загрузите датасет для предсказани цены квартиры в зависимости от ряда признаков.

# %%
import pandas as pd
import numpy as np
import sklearn as skl
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
data = pd.read_csv('train.csv')
data
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0     11809          27    3.0  115.027311         NaN           10.0      4
# 1      3013          22    1.0   39.832524   23.169223            8.0      7
# 2      8215           1    3.0   78.342215   47.671972           10.0      2
# 3      2352           1    1.0   40.409907         NaN            1.0     10
# 4     13866          94    2.0   64.285067   38.562517            9.0     16
# ...     ...         ...    ...         ...         ...            ...    ...
# 9995   1260          61    2.0   49.090728   33.272626            6.0      3
# 9996  16265          27    2.0   64.307684   37.038420            9.0     13
# 9997   2795         178    1.0   29.648057   16.555363            5.0      3
# 9998  14561          21    1.0   32.330292   22.326870            5.0      3
# 9999   7202          94    1.0   35.815476   22.301367            6.0      9
#
# ...

# %% [markdown]
# **Задание 1**
#
# Постройте круговую диаграмму для признака Rooms, иллюстрирующую количество квартир в процентах в зависимости от количества комнат. Сделайте сектор с наибольшим числом квартир выдвинутым.

# %%
a = data['Rooms'].value_counts()
labels = ['2 Комнаты', '1 Комната', '3 Комнаты', '4 and others']
plt.pie(a[:4], radius = 2.5, autopct = '%1.2f%%', labels = labels, explode = [0.075, 0, 0, 0], colors = ['darkgreen', 'green', 'chartreuse', 'lightgreen'])
plt.show()

# %% [markdown]
# **Задание 2**
#
# Постройте гистограмму целевой переменной Price. Оцените визуально, по какой цене продаётся наибольшее количество квартир.

# %%
plt.hist(data['Price'], color = 'yellowgreen')
plt.show()
print('Из визуальной оценки гистограммы видно, что большинство квартир продается по цене 200000')
# Out:
# Из визуальной оценки гистограммы видно, что большинство квартир продается по цене 200000

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# генерация данных для визуализации:
x_сol = np.linspace(0, 2*np.pi)
y_сol = np.sin(x_сol)

# При каком значении переменной v ячейка завершится с ошибкой?
v = 4 # варианты: 0, 1, 2, 3, 4

A = 1. 
сolors = ['bgrсmykw',
          [(0.0, 0.5, 0.0), (0.75, 0.75, 0.75), (0.25, 0.0, 1.0)],
          [str(с) for с in np.linspace(0.0, 1.0, 10)],
          ['bluе', 'orаngе', 'grееn', 'rеd', 'purplе', 'tаb:brown', 'tаb:pink', 'tаb:grаy', 'tаb:olivе'],
          [0x1f77b4, 0xafeee, 0x7f7f7f, 0x17becf]          
         ]

for с in сolors[v]:
     plt.plot(x_сol, A * y_сol, c=c, label=c)
     A *= 0.8
     plt.lеgеnd();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-ccd3f192e5df> in <module>
#      20
#      21 for с in сolors[v]:
# ---> 22      plt.plot(x_сol, A * y_сol, c=c, label=c)
#      23      A *= 0.8
#      24      plt.lеgеnd();
#
# NameError: name 'c' is not defined

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# генерация данных для визуализации:
x = np.linspace(0, 5, 20)
y1 = x ** 2
y2 = x ** 3
y3 = np.exp(x)

# При каком значении переменной v ячейка завершится с ошибкой?
v = 4 # Nonе # варианты: 1, 2, 3, 4, 5

fig, axi = plt.subplots(nrows=1, ncols=4, figsize=(12,3), layout='constrained', sharey='row')
i = 0

#-----
if v != 1:
    аx = аxi[i]
    i += 1

    аx.stеp(x, y1, с='с', whеrе='mid') 
#-----
if v != 2:
    аx = аxi[i]
    i += 1

    аx.bаr(x, y1)
#-----
if v != 3:
    аx = аxi[i]
    i += 1

    аx.sсаttеr(x, y1, сolor=[str(с) for с in y2/y2.mаx()], сmаp='infеrno')
#-----
if v != 4:
    аx = аxi[i]
    i += 1

    аx.sсаttеr(x, bins=y1, с=[с for с in y2], сmаp='hsv')
#-----
if v != 5:
    аx = аxi[i]
    i += 1

    аx.plot(x, y1[::-1], 'g')
    аx.sсаttеr(x, y1, y3, сolor=[str(с) for с in y2/y2.mаx()]);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-2abd9e81b93d> in <module>
#      13 v = 4 # Nonе # варианты: 1, 2, 3, 4, 5
#      14
# ---> 15 fig, axi = plt.subplots(nrows=1, ncols=4, figsize=(12,3), layout='constrained', sharey='row')
#      16 i = 0
#      17
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1175
#    1176     """
# -> 1177     fig = figure(**fig_kw)
#    1178     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1179                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     538             dpi = 72
#     539
# ...

# %% [markdown]
# **Задание 3**
#
# Постройте диаграммы рассеяния для признаков Rooms, Square, HouseFloor, HouseYear в зависимости от целевой переменной Price в одной области fiagure(). Оцените визуально, есть ли среди них такие, на которых разброс точек близок к линейной функции.

# %%
f = plt.figure(figsize = (16, 8))
ax = f.subplots(2,2)
ax[0, 0].scatter(data['Rooms'], data['Price'], color = 'indigo', alpha = 0.25, marker = 'X')
ax[0, 1].scatter(data['Square'], data['Price'], color = 'indigo', alpha = 0.25, marker = 'X')
ax[1, 0].scatter(data['HouseFloor'], data['Price'], color = 'indigo', alpha = 0.25, marker = 'X')
ax[1, 1].scatter(data['HouseYear'], data['Price'], color = 'indigo', alpha = 0.25, marker = 'X')

f.set(facecolor = 'tomato')
f.subplots_adjust(hspace=0.3, wspace=0)

ax[0,0].set(title = 'Rooms - Price', ylabel = 'Цена', xlabel = 'Комнаты')
ax[0,1].set(title = 'Square - Price', yticks = [], xlabel = 'Площадь')
ax[1,0].set(title = 'HouseFloor - Price', ylabel = 'Цена', xlabel = 'Максимум этажей в доме')
ax[1,1].set(title = 'HouseYear - Price', yticks = [], xlabel = 'Год постройки', xticks = [2010])
plt.suptitle('Диаграммы рассеивания', y = 1, fontsize=15)
plt.show()

# %% [markdown]
# **Задание 4**
#
# Постройте ядерную оценку плотности целевой переменной Price. Оцените визуально, напоминает ли полученный график нормальное распределение. Постройте двумерную ядерную оценку плотности для целевой переменной Price и признака HouseFloor, затем оцените визуально на каких этажах и по какой цене продаётся основная масса квартир.

# %%
sns.kdeplot(data['Price'], lw=3, label="Ядерная оценка плотности", shade=True, color = '#7FFF00')
plt.legend()
plt.show()

# %%
sns.kdeplot(x = data['Price'], y = data['HouseFloor'], label="Двумерная ядерная оценка плотности", cmap = 'viridis', shade = True, cbar = True)
plt.legend()
plt.show()

# %% [markdown]
# **Задание 5**
#
# Постройте ящиковую диаграмму признака Square. Оцените визуально имеются ли выбросы, и, если да, то начиная с какого размера площади значение признака можно считать выбросом.

# %%
l = sns.boxplot(data=data['Square'], color = 'lime');
l.set_title('Ящик с усами по Square')
l.set_ylabel('Площадь')
# Out:
# Text(0, 0.5, 'Площадь')

# %% [markdown]
# **Задание 6**
#
# При помощи сетки графиков PairGrid визуализируйте попарные отношения признаков Rooms, Square, HouseFloor, HouseYear, Price следующим образом: на диагонали - гистограммы, под диагональю - ядерные оценки плотности, над диагональю - диаграммы рассеяния. По результатам визуализации сделайте выводы (аналогичные п.2,3,4).

# %%
data_b=data.drop('Id', axis=1, inplace = True)
data_b=data.drop('DistrictId', axis=1, inplace = True)
data_b=data.drop('LifeSquare', axis=1, inplace = True)
data_b=data.drop('KitchenSquare', axis=1, inplace = True)
data_b=data.drop('Floor', axis=1, inplace = True)
data_b=data.drop('Ecology_1', axis=1, inplace = True)
data_b=data.drop('Ecology_2', axis=1, inplace = True)
data_b=data.drop('Ecology_3', axis=1, inplace = True)
data_b=data.drop('Social_1', axis=1, inplace = True)
data_b=data.drop('Social_2', axis=1, inplace = True)
data_b=data.drop('Social_3', axis=1, inplace = True)
data_b=data.drop('Healthcare_1', axis=1, inplace = True)
data_b=data.drop('Helthcare_2', axis=1, inplace = True)
data_b=data.drop('Shops_1', axis=1, inplace = True)
data_b=data.drop('Shops_2', axis=1, inplace = True)

# %%
data
# Out:
#       Rooms      Square  HouseFloor  HouseYear          Price
# 0       3.0  115.027311        10.0       2014  305018.871089
# 1       1.0   39.832524         8.0       1966  177734.553407
# 2       3.0   78.342215        17.0       1988  282078.720850
# 3       1.0   40.409907        22.0       1977  168106.007630
# 4       2.0   64.285067        16.0       1972  343995.102962
# ...     ...         ...         ...        ...            ...
# 9995    2.0   49.090728        12.0       1981  119367.455796
# 9996    2.0   64.307684         0.0       1977  199715.148807
# 9997    1.0   29.648057         5.0       1958  165953.912580
# 9998    1.0   32.330292         9.0       1969  171842.411855
# 9999    1.0   35.815476         9.0       1975  177685.627486
#
# [10000 rows x 5 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

сorpus = ['This is thе first doсumеnt.',
          'This doсumеnt is thе sесond doсumеnt.']

cv = TfidfVectorizer(norm=None).fit(сorpus)
x = cv.transform(сorpus).toarray()
print(x @ x.T)
# Out:
# [[5.97533217 5.        ]
#  [5.         8.97533217]]

# %% [markdown]
# **Задание 7**
#
# Постройте тепловую карту матрицы корреляции (df.corr()) признаков Rooms, Square, HouseFloor, HouseYear, Price. По ней определите, какие признаки являются зависимыми (у таких признаков коэффициент корреляции близок к единице).

# %%
numeric_col = ['Rooms', 'Square', 'HouseFloor', 'HouseYear', 'Price']
corr_matrix = data.loc[:, numeric_col].corr()
sns.heatmap(corr_matrix, annot = True, cmap = 'Reds', cbar = True, fmt='.1g', vmin= -1, vmax= 1, linewidths = 5, square = True)
plt.show()
